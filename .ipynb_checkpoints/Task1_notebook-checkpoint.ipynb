# %%
import pandas as pd 
import matplotlib.pyplot as plt

import numpy as np
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from argopy import DataFetcher as ArgoDataFetcher
argo_loader = ArgoDataFetcher()

ds = argo_loader.float([6902746, 6902747, 6902757, 6902766]).to_xarray()
df = ds.to_dataframe()

# Cleaning the data 
df.replace("", np.nan, inplace=True)
df.dropna()
df
# Out:
# /Users/vivekpatel/opt/anaconda3/envs/course_project_env/lib/python3.9/site-packages/argopy/stores/filesystems.py:18: UserWarning: argopy needs tqdm installed to display progress bars
#   warnings.warn("argopy needs tqdm installed to display progress bars")
# /Users/vivekpatel/opt/anaconda3/envs/course_project_env/lib/python3.9/site-packages/argopy/plotters.py:33: UserWarning: argopy requires cartopy installed for full map plotting functionality
#   warnings.warn("argopy requires cartopy installed for full map plotting functionality")
#           CONFIG_MISSION_NUMBER  CYCLE_NUMBER DATA_MODE DIRECTION  \
# N_POINTS
# 0                             1             1         D         D
# 1                             1             1         D         D
# 2                             1             1         D         D
# 3                             1             1         D         D
# 4                             1             1         D         D
# ...

# %%
data = pd.read_csv('argo_data.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149427 entries, 0 to 149426
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   LATITUDE                  149427 non-null  float64
#  1   LONGITUDE                 149427 non-null  float64
#  2   MONTH                     149427 non-null  object
#  3   YEAR                      149427 non-null  int64
#  4   PRESURE (db)              149427 non-null  float64
#  5   PRACTICAL SALINITY (psu)  149427 non-null  float64
#  6   TEMPERATURE (C)           149427 non-null  float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 8.0+ MB

# %%
plt.plot(data['YEAR'], data['PRESURE (db)'])
plt.title('Year Vs Presure')
plt.xlabel('Year')
plt.ylabel('Presure')
plt.show()

# %%
# Make a dropdown to select the Area, or "All"
year = widgets.Dropdown(
    options=['All'] + list(df['YEAR'].unique()),
    value='All',
    description='Year:',
)

# def plotit(year):
#     df2 = data.copy()
#     if year != 'All':
#             df2 = df2[df2.YEAR == year]
            
#     if len(df2) > 0:
#         df2.groupby(['Year', 'Sex']).sum()['Count'].unstack().plot(kind='bar', stacked=True, title="Area = {}".format(area))
#         plt.show();
#     else:
#         print("No data to show for current selection")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/course_project_env/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'YEAR'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-0771fcc7985a> in <module>
# ...

# %%
interactive(plotit, year=year)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-892ed6135e73> in <module>
# ----> 1 interactive(plotit, year=year)
#
# NameError: name 'plotit' is not defined
